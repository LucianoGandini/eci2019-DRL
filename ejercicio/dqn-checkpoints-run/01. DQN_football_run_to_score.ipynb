# %% [markdown]
# # Deep Q-Learning para _football_
#
# Autor: *Luciano Gandini*
#
# This work is licensed under the [GNU General Public License v3.0](https://choosealicense.com/licenses/gpl-3.0/).
#
# Aplicación del algoritmo DQN visto en la ECI 2019 para el entorno [_Football_](https://github.com/google-research/football) escenario `academy_run_to_score`.
#
# Ejecución local: requiere instalación según [instrucciones](https://github.com/jgromero/eci2019-DRL/blob/master/ejercicio/Instrucciones%20Entorno%20Football.pdf), no se precisa ninguna otra librería fuera de las mencionadas en el instructivo incluyendo el paso 7.
#
# <a href="http://www.youtube.com/watch?feature=player_embedded&v=F8DcgFDT9sc" target="_blank"><img src="http://img.youtube.com/vi/F8DcgFDT9sc/0.jpg"
# alt="IMAGE ALT TEXT HERE" width="580" border="3" /></a>

# %% [markdown]
# ## Iniciar entorno virtual
#
# En primer lugar, vamos a crear el ambiente football y el agente, este último tiene tres capas ocultas.
#
# El ambiente no renderizará el juego gráficamente para el entrenamiento, esto lo podremos ver ejecutando las siguientes notebooks.

# %%
import gfootball.env as football_env
from dqn_agent_simultaneous_update import Agent
from gfootball.env import football_action_set

env = football_env.create_environment(
    env_name='academy_run_to_score', 
    stacked=False,                           # solo estado, no pixeles 
    representation='simple115',              # solo estado, no pixeles 
    rewards='scoring,checkpoints',           # con recompensas intermedias.
    render=False)                            # mostrar graficamente

agent = Agent(state_size=115, action_size=21, seed=0)

# %% [markdown]
# ## Logging
# Deshabilitaremos el logging a nivel WARNING para reducer la verbosidad del entorno _football_.

# %%
import logging, os
logging.disable(logging.WARNING)

# %% [markdown]
# ## Algoritmo
#
# Como se informo previamente utilizaremos DQN para el agente con actualización simultanea, no se realizaron modificaciones a la implementación vista en clase.
#
# Se optó por variar la recompensa del ambiente multiplicandolo por diez y elevando el resultado al cubo, esto permite que al usar checkpoints los goles sean más valiosos y mantener una recompensa negativo al obtener un gol en contra.

# %%
import gym
import random
import torch
import numpy as np
from collections import deque
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
def dqn(n_episodes=10000, max_t=1000, eps_start=1.0, eps_end=0.01, eps_decay=0.995):
    """Deep Q-Learning.
    
    Params
    ======
        n_episodes (int): numero maximo de episodios de entrenamiento (n_episodios)
        max_t (int): numero maximo de pasos por episodio (n_entrenamiento)
        eps_start (float): valor inicial de epsilon
        eps_end (float): valor final de epsilon
        eps_decay (float): factor de multiplicacion (por episodio) de epsilon
    """
    scores = []                        # puntuaciones de cada episodio
    scores_window = deque(maxlen=50)  # puntuaciones de los ultimos 100 episodios
    eps = eps_start                    # inicializar epsilon
    for i_episode in range(1, n_episodes+1):
        state = env.reset()
        score = 0
        for t in range(max_t):
            
            # elegir accion At con politica e-greedy
            action = agent.act(state, eps)
            
            # aplicar At y obtener Rt+1, St+1
            next_state, reward, done, _ = env.step(action)
            
            # almacenar <St, At, Rt+1, St+1>
            agent.memory.add(state, action, (reward * 10) ** 3, next_state, done)
            
            # train & update
            agent.step(state, action, reward, next_state, done)
            
            # avanzar estado
            state = next_state
            score += reward
            
            if done:
                break 

        scores_window.append(score)       # guardar ultima puntuacion
        scores.append(score)              # guardar ultima puntuacion
        eps = max(eps_end, eps_decay*eps) # reducir epsilon
        
        #print('\rEpisodio {}\tPuntuacion media (ultimos {:d}): {:.2f}'.format(i_episode, 50, np.mean(scores_window)), end="")
        if i_episode % 50 == 0:
            print('\rEpisodio {}\tPuntuacion media ({:d} anteriores): {:.2f}'.format(i_episode, 50, np.mean(scores_window)))
            torch.save(agent.qnetwork_local.state_dict(), 'checkpoint.pth') # guardar pesos de agente entrenado
        if np.mean(scores_window)>=2.0:
            print('\nProblema resuelto en {:d} episodios!\tPuntuacion media (ultimos {:d}): {:.2f}'.format(i_episode-50, 50, np.mean(scores_window)))
            torch.save(agent.qnetwork_local.state_dict(), 'checkpoint.pth') # guardar pesos de agente entrenado
            break
    return scores

scores = dqn()

# plot the scores
fig = plt.figure()
ax = fig.add_subplot(111)
plt.plot(np.arange(len(scores)), scores)
plt.ylabel('Puntuacion')
plt.xlabel('Episodio #')
plt.show()
# Out:
# Episodio 50	Puntuacion media (50 anteriores): 0.08
# Episodio 100	Puntuacion media (50 anteriores): 0.19
# Episodio 150	Puntuacion media (50 anteriores): 0.11
# Episodio 200	Puntuacion media (50 anteriores): 0.02
# Episodio 250	Puntuacion media (50 anteriores): -0.03
# Episodio 300	Puntuacion media (50 anteriores): 0.13
# Episodio 350	Puntuacion media (50 anteriores): 0.38
# Episodio 400	Puntuacion media (50 anteriores): 0.43
# Episodio 450	Puntuacion media (50 anteriores): 0.30
# Episodio 500	Puntuacion media (50 anteriores): 0.27
# Episodio 550	Puntuacion media (50 anteriores): 0.42
# Episodio 600	Puntuacion media (50 anteriores): 0.41
# Episodio 650	Puntuacion media (50 anteriores): 0.41
# Episodio 700	Puntuacion media (50 anteriores): 0.40
# Episodio 750	Puntuacion media (50 anteriores): 0.25
# Episodio 800	Puntuacion media (50 anteriores): 0.26
# Episodio 850	Puntuacion media (50 anteriores): 0.29
# Episodio 900	Puntuacion media (50 anteriores): 0.24
# Episodio 950	Puntuacion media (50 anteriores): 0.36
# Episodio 1000	Puntuacion media (50 anteriores): 0.46
# Episodio 1050	Puntuacion media (50 anteriores): 0.45
# Episodio 1100	Puntuacion media (50 anteriores): 0.83
# Episodio 1150	Puntuacion media (50 anteriores): 0.64
# Episodio 1200	Puntuacion media (50 anteriores): 0.43
# Episodio 1250	Puntuacion media (50 anteriores): 0.53
# Episodio 1300	Puntuacion media (50 anteriores): 1.00
# Episodio 1350	Puntuacion media (50 anteriores): 1.26
# Episodio 1400	Puntuacion media (50 anteriores): 1.34
# Episodio 1450	Puntuacion media (50 anteriores): 1.17
# Episodio 1500	Puntuacion media (50 anteriores): 1.38
# Episodio 1550	Puntuacion media (50 anteriores): 1.27
# Episodio 1600	Puntuacion media (50 anteriores): 1.34
# Episodio 1650	Puntuacion media (50 anteriores): 1.27
# Episodio 1700	Puntuacion media (50 anteriores): 1.25
# Episodio 1750	Puntuacion media (50 anteriores): 1.33
# Episodio 1800	Puntuacion media (50 anteriores): 0.78
# Episodio 1850	Puntuacion media (50 anteriores): 1.00
# Episodio 1900	Puntuacion media (50 anteriores): 1.07
# Episodio 1950	Puntuacion media (50 anteriores): 0.68
# Episodio 2000	Puntuacion media (50 anteriores): 1.33
# Episodio 2050	Puntuacion media (50 anteriores): 1.33
# Episodio 2100	Puntuacion media (50 anteriores): 1.11
# Episodio 2150	Puntuacion media (50 anteriores): 1.39
# Episodio 2200	Puntuacion media (50 anteriores): 1.36
# Episodio 2250	Puntuacion media (50 anteriores): 1.38
# Episodio 2300	Puntuacion media (50 anteriores): 1.62
# Episodio 2350	Puntuacion media (50 anteriores): 1.42
# Episodio 2400	Puntuacion media (50 anteriores): 1.52
# Episodio 2450	Puntuacion media (50 anteriores): 1.38
# Episodio 2500	Puntuacion media (50 anteriores): 1.38
# Episodio 2550	Puntuacion media (50 anteriores): 1.45
# Episodio 2600	Puntuacion media (50 anteriores): 1.51
# Episodio 2650	Puntuacion media (50 anteriores): 1.44
# Episodio 2700	Puntuacion media (50 anteriores): 1.69
# Episodio 2750	Puntuacion media (50 anteriores): 1.45
# Episodio 2800	Puntuacion media (50 anteriores): 1.54
# Episodio 2850	Puntuacion media (50 anteriores): 1.55
# Episodio 2900	Puntuacion media (50 anteriores): 1.46
# Episodio 2950	Puntuacion media (50 anteriores): 1.08
# Episodio 3000	Puntuacion media (50 anteriores): 1.36
# Episodio 3050	Puntuacion media (50 anteriores): 1.26
# Episodio 3100	Puntuacion media (50 anteriores): 1.25
# Episodio 3150	Puntuacion media (50 anteriores): 1.44
# Episodio 3200	Puntuacion media (50 anteriores): 1.33
# Episodio 3250	Puntuacion media (50 anteriores): 1.36
# Episodio 3300	Puntuacion media (50 anteriores): 1.20
# Episodio 3350	Puntuacion media (50 anteriores): 1.24
# Episodio 3400	Puntuacion media (50 anteriores): 1.34
# Episodio 3450	Puntuacion media (50 anteriores): 1.35
# Episodio 3500	Puntuacion media (50 anteriores): 1.52
# Episodio 3550	Puntuacion media (50 anteriores): 1.57
# Episodio 3600	Puntuacion media (50 anteriores): 1.62
# Episodio 3650	Puntuacion media (50 anteriores): 1.79
# Episodio 3700	Puntuacion media (50 anteriores): 1.46
# Episodio 3750	Puntuacion media (50 anteriores): 1.61
# Episodio 3800	Puntuacion media (50 anteriores): 1.50
# Episodio 3850	Puntuacion media (50 anteriores): 1.62
# Episodio 3900	Puntuacion media (50 anteriores): 1.56
# Episodio 3950	Puntuacion media (50 anteriores): 1.60
# Episodio 4000	Puntuacion media (50 anteriores): 1.62
# Episodio 4050	Puntuacion media (50 anteriores): 1.68
# Episodio 4100	Puntuacion media (50 anteriores): 1.67
# Episodio 4150	Puntuacion media (50 anteriores): 1.50
# Episodio 4200	Puntuacion media (50 anteriores): 1.68
# Episodio 4250	Puntuacion media (50 anteriores): 1.69
# Episodio 4300	Puntuacion media (50 anteriores): 1.56
# Episodio 4350	Puntuacion media (50 anteriores): 1.60
# Episodio 4400	Puntuacion media (50 anteriores): 1.63
# Episodio 4450	Puntuacion media (50 anteriores): 1.58
# Episodio 4500	Puntuacion media (50 anteriores): 1.71
# Episodio 4550	Puntuacion media (50 anteriores): 1.64
# Episodio 4600	Puntuacion media (50 anteriores): 1.54
# Episodio 4650	Puntuacion media (50 anteriores): 1.73
# Episodio 4700	Puntuacion media (50 anteriores): 1.52
# Episodio 4750	Puntuacion media (50 anteriores): 1.79
# Episodio 4800	Puntuacion media (50 anteriores): 1.81
# Episodio 4850	Puntuacion media (50 anteriores): 1.62
# Episodio 4900	Puntuacion media (50 anteriores): 1.52
# Episodio 4950	Puntuacion media (50 anteriores): 1.58
# Episodio 5000	Puntuacion media (50 anteriores): 1.75
# Episodio 5050	Puntuacion media (50 anteriores): 1.50
# Episodio 5100	Puntuacion media (50 anteriores): 1.73
# Episodio 5150	Puntuacion media (50 anteriores): 1.66
# Episodio 5200	Puntuacion media (50 anteriores): 1.50
# Episodio 5250	Puntuacion media (50 anteriores): 1.48
# Episodio 5300	Puntuacion media (50 anteriores): 1.71
# Episodio 5350	Puntuacion media (50 anteriores): 1.50
# Episodio 5400	Puntuacion media (50 anteriores): 1.65
# Episodio 5450	Puntuacion media (50 anteriores): 1.71
# Episodio 5500	Puntuacion media (50 anteriores): 1.31
# Episodio 5550	Puntuacion media (50 anteriores): 1.31
# Episodio 5600	Puntuacion media (50 anteriores): 1.39
# Episodio 5650	Puntuacion media (50 anteriores): 1.60
# Episodio 5700	Puntuacion media (50 anteriores): 1.77
# Episodio 5750	Puntuacion media (50 anteriores): 1.41
# Episodio 5800	Puntuacion media (50 anteriores): 1.59
# Episodio 5850	Puntuacion media (50 anteriores): 1.18
# Episodio 5900	Puntuacion media (50 anteriores): 1.62
# Episodio 5950	Puntuacion media (50 anteriores): 1.71
# Episodio 6000	Puntuacion media (50 anteriores): 1.73
# Episodio 6050	Puntuacion media (50 anteriores): 1.58
# Episodio 6100	Puntuacion media (50 anteriores): 1.62
# Episodio 6150	Puntuacion media (50 anteriores): 1.43
# Episodio 6200	Puntuacion media (50 anteriores): 1.28
# Episodio 6250	Puntuacion media (50 anteriores): 1.85
# Episodio 6300	Puntuacion media (50 anteriores): 1.34
# Episodio 6350	Puntuacion media (50 anteriores): 1.14
# Episodio 6400	Puntuacion media (50 anteriores): 1.41
# Episodio 6450	Puntuacion media (50 anteriores): 1.27
# Episodio 6500	Puntuacion media (50 anteriores): 1.66
# Episodio 6550	Puntuacion media (50 anteriores): 1.67
# Episodio 6600	Puntuacion media (50 anteriores): 0.97
# Episodio 6650	Puntuacion media (50 anteriores): 1.71
# Episodio 6700	Puntuacion media (50 anteriores): 1.56
# Episodio 6750	Puntuacion media (50 anteriores): 1.50
# Episodio 6800	Puntuacion media (50 anteriores): 1.75
# Episodio 6850	Puntuacion media (50 anteriores): 1.47
# Episodio 6900	Puntuacion media (50 anteriores): 1.82
# Episodio 6950	Puntuacion media (50 anteriores): 1.21
# Episodio 7000	Puntuacion media (50 anteriores): 1.33
# Episodio 7050	Puntuacion media (50 anteriores): 1.18
# Episodio 7100	Puntuacion media (50 anteriores): 1.55
# Episodio 7150	Puntuacion media (50 anteriores): 1.65
# Episodio 7200	Puntuacion media (50 anteriores): 1.77
# Episodio 7250	Puntuacion media (50 anteriores): 1.58
# Episodio 7300	Puntuacion media (50 anteriores): 1.82
# Episodio 7350	Puntuacion media (50 anteriores): 1.71
# Episodio 7400	Puntuacion media (50 anteriores): 1.60
# Episodio 7450	Puntuacion media (50 anteriores): 1.37
# Episodio 7500	Puntuacion media (50 anteriores): 1.56
# Episodio 7550	Puntuacion media (50 anteriores): 1.54
# Episodio 7600	Puntuacion media (50 anteriores): 1.77
# Episodio 7650	Puntuacion media (50 anteriores): 1.36
# Episodio 7700	Puntuacion media (50 anteriores): 1.60
# Episodio 7750	Puntuacion media (50 anteriores): 1.69
# Episodio 7800	Puntuacion media (50 anteriores): 1.45
# Episodio 7850	Puntuacion media (50 anteriores): 1.43
# Episodio 7900	Puntuacion media (50 anteriores): 1.31
# Episodio 7950	Puntuacion media (50 anteriores): 1.47
# Episodio 8000	Puntuacion media (50 anteriores): 1.60
# Episodio 8050	Puntuacion media (50 anteriores): 1.46
# Episodio 8100	Puntuacion media (50 anteriores): 1.63
# Episodio 8150	Puntuacion media (50 anteriores): 1.42
# Episodio 8200	Puntuacion media (50 anteriores): 1.69
# Episodio 8250	Puntuacion media (50 anteriores): 1.54
# Episodio 8300	Puntuacion media (50 anteriores): 1.11
# Episodio 8350	Puntuacion media (50 anteriores): 1.60
# Episodio 8400	Puntuacion media (50 anteriores): 1.56
# Episodio 8450	Puntuacion media (50 anteriores): 1.58
# Episodio 8500	Puntuacion media (50 anteriores): 1.81
# Episodio 8550	Puntuacion media (50 anteriores): 1.58
# Episodio 8600	Puntuacion media (50 anteriores): 1.54
# Episodio 8650	Puntuacion media (50 anteriores): 1.49
# Episodio 8700	Puntuacion media (50 anteriores): 1.47
# Episodio 8750	Puntuacion media (50 anteriores): 1.65
# Episodio 8800	Puntuacion media (50 anteriores): 1.34
# Episodio 8850	Puntuacion media (50 anteriores): 1.33
# Episodio 8900	Puntuacion media (50 anteriores): 1.58
# Episodio 8950	Puntuacion media (50 anteriores): 1.26
# Episodio 9000	Puntuacion media (50 anteriores): 1.69
# Episodio 9050	Puntuacion media (50 anteriores): 1.47
# Episodio 9100	Puntuacion media (50 anteriores): 1.44
# Episodio 9150	Puntuacion media (50 anteriores): 1.43
# Episodio 9200	Puntuacion media (50 anteriores): 1.52
# Episodio 9250	Puntuacion media (50 anteriores): 1.54
# Episodio 9300	Puntuacion media (50 anteriores): 1.38
# Episodio 9350	Puntuacion media (50 anteriores): 1.47
# Episodio 9400	Puntuacion media (50 anteriores): 1.52
# Episodio 9450	Puntuacion media (50 anteriores): 1.56
# Episodio 9500	Puntuacion media (50 anteriores): 1.47
# Episodio 9550	Puntuacion media (50 anteriores): 1.60
# Episodio 9600	Puntuacion media (50 anteriores): 1.35
# Episodio 9650	Puntuacion media (50 anteriores): 1.56
# Episodio 9700	Puntuacion media (50 anteriores): 1.62
# Episodio 9750	Puntuacion media (50 anteriores): 1.62
# Episodio 9800	Puntuacion media (50 anteriores): 1.50
# Episodio 9850	Puntuacion media (50 anteriores): 1.66
# Episodio 9900	Puntuacion media (50 anteriores): 1.52
# Episodio 9950	Puntuacion media (50 anteriores): 1.52
# Episodio 10000	Puntuacion media (50 anteriores): 1.54

# %% [markdown]
# ## Resultado
#
# En este caso el algoritmo no logra obtener una puntuacion optima y al finalizar las iteraciones obtendremos la siguiente salida:
#
# _Episodio 10000	Puntuacion media (50 anteriores): 1.54_
#
# Sin embargo si se corre manualmente *03. DQN_runonly_final* como se indica a continuación se ve que el agente aprendió a realizar los goles correctamente, decrementando el épsilon final (eps_end) es probable que se pueda obtener una mayor puntuación pero no le permite al agente encontrar esta estrategia en la misma cantidad de iteraciones.

# %% [markdown]
# ## Reproducir el experimento
#
# Se puede ejecutar la notebook corriendo todas las etapas, si se dese observar el avance del entrenamiento durante la ejecución se recomienda ejecutar la notebook *02. DQN_runonly* que utilizara el checkpoint de salida de este algoritmo.
#
# Se ha incluido también un checkpoint del resultado obtenido en el experimento con el resultado anterior, para ver al agente entrenado con ese modelo ejecutar la notebook *03. DQN_runonly_final*.
